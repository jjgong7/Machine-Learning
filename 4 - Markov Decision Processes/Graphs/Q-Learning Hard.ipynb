# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from collections import defaultdict

# %%
files = glob.glob('../Solution/Hard Q-Learning*.csv')
files.sort()
#File name beginining
nb = 27
#File name ending
ne = -4
#Output file
#name = 'tsp.csv'

# %%
files = dict(enumerate(files))
files
# Out:
# {0: '../Solution/Hard Q-Learning L0.1 E0.3.csv',
#  1: '../Solution/Hard Q-Learning L0.1 E0.5.csv',
#  2: '../Solution/Hard Q-Learning L0.1 E0.7.csv',
#  3: '../Solution/Hard Q-Learning L0.1 E0.9.csv'}

# %%
dfs = defaultdict(int)
for indx, f in files.items():
    dfs[indx] = pd.read_csv(f)

# %%
dfs[0][:5]
# Out:
#    iter        time  reward  steps  convergence
# 0     1  174.451666  -308.0  300.0     9.891000
# 1     2   54.218282  -326.0  300.0     9.709815
# 2     3    8.219264  -299.0  300.0     9.373054
# 3     4   27.863095  -308.0  300.0     8.961909
# 4     5   14.462880  -308.0  300.0     8.475209

# %% [markdown]
# ## Iterations vs Time

# %%
ax = plt.subplot(111)

for indx, d in dfs.items():
    ax.plot(d[['iter']],d[['time']], label = files[indx][nb:ne])

plt.ylim(0, 20)
plt.xlim(0, 500)
plt.ylabel("Time (in ms)")
plt.xlabel("Iterations")
plt.title('Q-Learning: Iterations vs. Time')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Steps

# %%
ax = plt.subplot(111)

for indx, d in dfs.items():
    ax.plot(d[['iter']],d[['steps']], label = files[indx][nb:ne])

plt.ylim(25, 100)
plt.xlim(0, 500)
plt.ylabel("Steps")
plt.xlabel("Iterations")
plt.title('Q-Learning: Iterations vs. Steps')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Convergence

# %%
ax = plt.subplot(111)

for indx, d in dfs.items():
    ax.plot(d[['iter']],d[['convergence']], label = files[indx][nb:ne])

plt.ylim(0, 10)
plt.xlim(0, 500)
plt.ylabel("Convergence")
plt.xlabel("Iterations")
plt.title('Q-Learning: Iterations vs. Convergence')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Reward

# %%
ax = plt.subplot(111)

for indx, d in dfs.items():
    ax.plot(d[['iter']],d[['reward']], label = files[indx][nb:ne])

plt.ylim(-100, 75)
plt.xlim(0, 500)
plt.ylabel("Reward")
plt.xlabel("Iterations")
plt.title('Q-Learning: Iterations vs. Reward')
ax.legend()
plt.show()
